# %% [markdown]
# # DC crime analysis
#
# This script covers the three main topics distributed in **10 objectives**. The topics and objectives are:
#
#  * Topic: Handling .xml files
#      * **Objective 1**: To read the .xml data files with the crime reports from 2011, 2012 and 2013 and then print them out as a dataframe.
#      * **Objective 2**. Find the total number of registered offenses that took place in 2011, 2012 and 2013 and see if there is a trend on this.
#
#  * Statistical analysis:
#      * **Objective 3**. Check the different type of crimes and their proportion per year.
#      * **Objective 4**. Find the the probability of NOT being affected by any type of crime
#      * **Objective 5**. Find the probability per type of crime and check if they follow any trend
#      * **Objective 6**. Crime proportion distributions per Wards and their trends
#      * **Objective 7**. Crime distribution per day's shift. Statistical analysis.
#      * **Objective 8**. Find the crime distribution per months.
#      * **Objective 9**. Find if there is a correlation between the daily temperatures and the crime incident number
#      * **Objective 10**: Crime frequency per street. Bubble plots.
#  * Scrapping data from a web site:
#      * **Objective 9**. Find if there is a correlation between the daily temperatures and the crime incident number

# %%
from __future__ import division
from StringIO import StringIO
import pandas as pd
import numpy as np
from xml.dom import minidom
import matplotlib.pyplot as plt
plt.style.use('ggplot')
#import itertools
#import plotly.plotly as py
#from plotly.graph_objs import *
from pylab import *
# %pylab inline
from mpl_toolkits.axes_grid1 import make_axes_locatable
import bokeh.plotting as bkp
import seaborn

from scipy.interpolate import *
from scipy.stats import *
from numpy import *
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['linalg', 'draw_if_interactive', 'random', 'power', 'info', 'fft']
# `%matplotlib` prevents importing * from pylab and numpy
#
#         <style>
#             /* BEGIN /Users/paudiazgallifa/anaconda/lib/python2.7/site-packages/bokeh/server/static/css/bokeh.min.css */
# ...

# %% [markdown]
# ##**Objective 1:** To read the .xml data files with the crime reports from 2011, 2012 and 2013 and then print them out as a dataframe.
#
# * With the aim of extracting the crime incidents data from the xml data file I built up a function called "*dataframe_builder*"
# that takes the file name as argument.

# %%
def dataframe_builder(datafile):
    
    datafile=str(datafile)
    
    xmldoc = minidom.parse(datafile)
    itemlist = xmldoc.getElementsByTagName('dcst:ReportedCrime')
    
    OF=[]
    Wards=[]
    Dates=[]
    days=[]
    Streets=[]
    Shift=[]

    wards=['Ward1','Ward2','Ward3','Ward4','Ward5','Ward6','Ward7','Ward8']

    #Extraemos la info del xml siguendo el video de https://www.youtube.com/watch?v=c2qlCZhkwtE
    for s in itemlist[0:-1]:
        try:
            offenses=s.getElementsByTagName('dcst:offense')[0].firstChild.data
            ward=s.getElementsByTagName('dcst:ward')[0].firstChild.data 
            date=s.getElementsByTagName('dcst:reportdatetime')[0].firstChild.data
            street=s.getElementsByTagName('dcst:blocksiteaddress')[0].firstChild.data
            shift=s.getElementsByTagName('dcst:shift')[0].firstChild.data
            OF.append(offenses)
            Wards.append(ward)
            Dates.append(date)
            days.append(date.split('T')[0])
            Streets.append(street)
            Shift.append(shift)
        except:
            continue
    df = pd.DataFrame({'Ward' : Wards, 'Offenses':OF, 'Reported_Date':Dates, 'Street':Streets, 'Shifts':Shift, 'Days':days})
    return df

# %%
df2013=dataframe_builder('crime_incidents_2013_plain.xml')
df2012=dataframe_builder('crime_incidents_2012_plain.xml')
df2011=dataframe_builder('crime_incidents_2011_plain.xml')

# %% [markdown]
# The dataframe shown here below shows some of the selected crime details for the reported incidents.

# %%
df2011.set_index('Reported_Date').sort().head()
# Out:
#                                  Days                    Offenses    Shifts  \
# Reported_Date
# 2011-01-01T00:50:00-05:00  2011-01-01                     ROBBERY  MIDNIGHT
# 2011-01-01T01:05:00-05:00  2011-01-01                THEFT F/AUTO  MIDNIGHT
# 2011-01-01T01:28:00-05:00  2011-01-01                     ROBBERY  MIDNIGHT
# 2011-01-01T02:00:00-05:00  2011-01-01  ASSAULT W/DANGEROUS WEAPON  MIDNIGHT
# 2011-01-01T02:04:00-05:00  2011-01-01                THEFT F/AUTO  MIDNIGHT
#
#                                                               Street Ward
# Reported_Date
# 2011-01-01T00:50:00-05:00  1700 - 1723 BLOCK OF NORTH CAPITOL STREET    5
# 2011-01-01T01:05:00-05:00         1000 - 1099 BLOCK OF 4TH STREET NW    6
# 2011-01-01T01:28:00-05:00             400 - 499 BLOCK OF M STREET SW    6
# 2011-01-01T02:00:00-05:00          HIGH STREET SE AND 14TH STREET SE    8
# 2011-01-01T02:04:00-05:00             I STREET NW AND 17TH STREET NW    2

# %% [markdown]
# ##**Objective 2**. Find the total number of registered offenses that took place in 2011, 2012 and 2013 and see if there is a trend on this.

# %%
print "Total number of offenses in 2011:", df2011.Offenses.value_counts().sum(), ". In 2012:", df2012.Offenses.value_counts().sum(), ". And in 2013:",df2013.Offenses.value_counts().sum()
# Out:
# Total number of offenses in 2011: 33962 . In 2012: 35435 . And in 2013: 35896

# %% [markdown]
# These numbers show as the total number of incidents increased year by year from 2011 to 2013. However in 2013 this number increased much less than the previous ones.
#
#
#
#
#
# ##Objective 3. Check the different type of crimes and their proportion per year.

# %%
df_offenses=pd.DataFrame({'2011':df2011.Offenses.value_counts(),'2012':df2012.Offenses.value_counts(),'2013':df2013.Offenses.value_counts()})

# %%
def calc_percent_per_offense(df,year):
    '''Calculates the distribution offense percentages per year'''
    total=df.Offenses.value_counts().sum()
    year=str(year)
    percent_df=pd.DataFrame({year+'_Percentage(%)':((df.Offenses.value_counts()/total)*100.0)})
    return percent_df

#df_percent_offencese=pf.DataFrame({"2011 (%)": calc_percent_per_offense(df2011).
dfs= [calc_percent_per_offense(df2011,2011),calc_percent_per_offense(df2012,2012),calc_percent_per_offense(df2013,2013)]

df_percent_offenses=pd.concat(dfs, axis=1)
df_percent_offenses
# Out:
#                             2011_Percentage(%)  2012_Percentage(%)  \
# THEFT/OTHER                          31.785525           35.216594
# THEFT F/AUTO                         27.015488           26.713701
# ROBBERY                              12.254873           12.047411
# BURGLARY                             11.636535           10.390856
# MOTOR VEHICLE THEFT                   9.937577            8.079582
# ASSAULT W/DANGEROUS WEAPON            6.415994            6.476647
# SEX ABUSE                             0.506448            0.728094
# HOMICIDE                              0.318002            0.248342
# ARSON                                 0.129557            0.098772
#
#                             2013_Percentage(%)
# THEFT/OTHER                          35.923223
# THEFT F/AUTO                         28.228772
# ROBBERY                              11.346668
# BURGLARY                              9.385447
# MOTOR VEHICLE THEFT                   7.457655
# ...

# %%
df_offenses.plot(kind='pie', subplots=True, figsize=(16, 4),legend=False, labels=None, title="DC criminal activity distribution 2011, 2012 and 2013",
                colors=['0.75','0.80','0.85','0.90','0.95','r','r','r','r'])

savefig('types_crime_proportion_per_year.png')

# %%
df_percent_offenses["2011_Percentage(%)"]
# Out:
# THEFT/OTHER                   31.785525
# THEFT F/AUTO                  27.015488
# ROBBERY                       12.254873
# BURGLARY                      11.636535
# MOTOR VEHICLE THEFT            9.937577
# ASSAULT W/DANGEROUS WEAPON     6.415994
# SEX ABUSE                      0.506448
# HOMICIDE                       0.318002
# ARSON                          0.129557
# Name: 2011_Percentage(%), dtype: float64

# %%
df_percent_offenses["2012_Percentage(%)"]
# Out:
# THEFT/OTHER                   35.216594
# THEFT F/AUTO                  26.713701
# ROBBERY                       12.047411
# BURGLARY                      10.390856
# MOTOR VEHICLE THEFT            8.079582
# ASSAULT W/DANGEROUS WEAPON     6.476647
# SEX ABUSE                      0.728094
# HOMICIDE                       0.248342
# ARSON                          0.098772
# Name: 2012_Percentage(%), dtype: float64

# %%
df_percent_offenses["2013_Percentage(%)"]
# Out:
# THEFT/OTHER                   35.923223
# THEFT F/AUTO                  28.228772
# ROBBERY                       11.346668
# BURGLARY                       9.385447
# MOTOR VEHICLE THEFT            7.457655
# ASSAULT W/DANGEROUS WEAPON     6.438043
# SEX ABUSE                      0.832962
# HOMICIDE                       0.289726
# ARSON                          0.097504
# Name: 2013_Percentage(%), dtype: float64

# %% [markdown]
# ## Objective 4. Find the the probability of NOT being affected by any type of crime
# Lets see what was the probability of NOT being affected by any type of crime
# for a person who lived in DC the whole 2011, 2012 or 2013.
# Define the random variable X: to be 100% safe in DC, and Y: to be attacked during
# any of the 365 days of any of these years at any location inside of DC
#
# P(X) = 1 - P(Y)
#
# P(Y) = ( number of outcomes / total number of possible outcomes )
#
# in our case:
#
# P(Y) = (number of crime reported incidents / total of DC inhabitants)

# %%
# populations 
po2011=620427 #population_2011: http://www.census.gov/popest/estimates.html
po2012=635040 #population_2012: http://www.census.gov/popest/estimates.html
po2013=649111 #population_2011: http://www.census.gov/popest/estimates.html 

def prob_safety(df,population):
    PY= df.Offenses.value_counts().sum() / population
    # Then P(X)=1-P(Y)
    PX=round((1-PY)*100,2)
    return PX

safety_prob_2011=prob_safety(df2011,po2011)
safety_prob_2012=prob_safety(df2011,po2012)
safety_prob_2013=prob_safety(df2011,po2013)

print "The probabilities of NOT being affected by any type of crime in 2011, 2012 and 2013 were:",  safety_prob_2011,"%",safety_prob_2012,"%", safety_prob_2013,"%"
# Out:
# The probabilities of NOT being affected by any type of crime in 2011, 2012 and 2013 were: 94.53 % 94.65 % 94.77 %

# %% [markdown]
# ##Objective 5. Find the probability per type of crime and check if they follow any trend
# Lets see what are the probabilities per type of crime for a person who is living at any place in the city during 2011, 2012 or 2013.

# %%
def P_offense_type(dataframe,population,year):
    '''calculates the probability that an inhabitant had during the given year 
    of being involved in the different reported crimes'''
    OF=[]
    Probs=[]
    year=str(year)
    for i,j in zip(dataframe.Offenses.value_counts().keys(),dataframe.Offenses.value_counts()):
       
        OF.append(i)
        Probs.append(round((j/population)*100,2))
    probs_crime_types_df=pd.DataFrame({'Offenses':OF, year+'_Probability(%)':Probs})
    return probs_crime_types_df



df_offense_type2011=P_offense_type(df2011,po2011,2011).set_index('Offenses')
df_offense_type2012=P_offense_type(df2012,po2012,2012).set_index('Offenses')
df_offense_type2013=P_offense_type(df2013,po2013,2013).set_index('Offenses')

dfs_per_crime=[df_offense_type2011,df_offense_type2012,df_offense_type2013]

df_percent_per_crime=pd.concat(dfs_per_crime, axis=1)
df_percent_per_crime
# Out:
#                             2011_Probability(%)  2012_Probability(%)  \
# Offenses
# THEFT/OTHER                                1.74                 1.97
# THEFT F/AUTO                               1.48                 1.49
# ROBBERY                                    0.67                 0.67
# BURGLARY                                   0.64                 0.58
# MOTOR VEHICLE THEFT                        0.54                 0.45
# ASSAULT W/DANGEROUS WEAPON                 0.35                 0.36
# SEX ABUSE                                  0.03                 0.04
# HOMICIDE                                   0.02                 0.01
# ARSON                                      0.01                 0.01
#
#                             2013_Probability(%)
# Offenses
# THEFT/OTHER                                1.99
# THEFT F/AUTO                               1.56
# ROBBERY                                    0.63
# BURGLARY                                   0.52
# ...

# %% [markdown]
# Let's plot these results:

# %%
df_percent_per_crime.unstack().unstack()
# Out:
# Offenses             THEFT/OTHER  THEFT F/AUTO  ROBBERY  BURGLARY  \
# 2011_Probability(%)         1.74          1.48     0.67      0.64
# 2012_Probability(%)         1.97          1.49     0.67      0.58
# 2013_Probability(%)         1.99          1.56     0.63      0.52
#
# Offenses             MOTOR VEHICLE THEFT  ASSAULT W/DANGEROUS WEAPON  \
# 2011_Probability(%)                 0.54                        0.35
# 2012_Probability(%)                 0.45                        0.36
# 2013_Probability(%)                 0.41                        0.36
#
# Offenses             SEX ABUSE  HOMICIDE  ARSON
# 2011_Probability(%)       0.03      0.02   0.01
# 2012_Probability(%)       0.04      0.01   0.01
# 2013_Probability(%)       0.05      0.02   0.01

# %% [markdown]
# How has been the **trend** of these probabilities during these three years?

# %%
fig, axes = plt.subplots(nrows=3, ncols=3)


df_percent_per_crime.unstack().unstack()["THEFT/OTHER"].plot(figsize=(14,12),marker='o',color="0.6",legend=True,ax=axes[0,0])
df_percent_per_crime.unstack().unstack()["THEFT F/AUTO"].plot(figsize=(14,12),legend=True,marker='o',color="0.6",ax=axes[0,1])
df_percent_per_crime.unstack().unstack()["ROBBERY"].plot(figsize=(14,12),legend=True,marker='o',color="0.6",ax=axes[0,2])
df_percent_per_crime.unstack().unstack()["BURGLARY"].plot(figsize=(14,12),legend=True,marker='o',color="0.6",ax=axes[1,0])
df_percent_per_crime.unstack().unstack()["MOTOR VEHICLE THEFT"].plot(figsize=(14,12),legend=True,marker='o',color="0.6",ax=axes[1,1])
df_percent_per_crime.unstack().unstack()["ASSAULT W/DANGEROUS WEAPON"].plot(figsize=(14,12),legend=True,marker='o',color="r",ax=axes[1,2])
df_percent_per_crime.unstack().unstack()["SEX ABUSE"].plot(figsize=(14,12),legend=True,marker='o',color="r",ax=axes[2,0])
df_percent_per_crime.unstack().unstack()["HOMICIDE"].plot(figsize=(14,12),legend=True,marker='o',color="r",ax=axes[2,1])
df_percent_per_crime.unstack().unstack()["ARSON"].plot(figsize=(14,12),legend=True,marker='o',color="r",ax=axes[2,2])

# %% [markdown]
# ##Objective 6. Crime proportion distributions per Wards and their trends
# Lets see now how the reported incidents are distributed through the 8 wards. Which is the ward percentage of the total crime reported in DC:

# %%
crime_ward_df_per_years=pd.DataFrame({"2011":df2011.Ward.value_counts(),"2012":df2012.Ward.value_counts(),"2013":df2013.Ward.value_counts()})

crime_ward_df_per_years.plot(kind='pie', subplots=True,autopct='%.2f', figsize=(16, 5),legend=False, title="Probabilities per type of crime",
                colors=['0.75','0.80','0.85','0.90','0.95','0.65','0.55','0.45','0.35'],
                            labels=("Ward1","Ward2","Ward3","Ward4","Ward5","Ward6","Ward7","Ward8"))

plt.savefig("Crime_proportion_per_ward.png", dpi=300) # save as png

# %% [markdown]
# And hereunder we have the evolution of the **number of crimes over time** (from 2011 to 2013).

# %%
crime_ward_df_per_years.unstack().unstack()
# Out:
#          1     2     3     4     5     6     7     8
# 2011  5026  6300  1941  2960  4381  4951  4064  4339
# 2012  5060  6537  1783  3000  4802  5512  4342  4399
# 2013  5407  5953  1938  3263  4616  5670  4615  4434

# %%
fig, axes = plt.subplots(nrows=2, ncols=4)

crime_ward_df_per_years.unstack().unstack()["1"].plot(figsize=(16,8),label="Ward1",legend=True,marker='o',color="0.6",ax=axes[0,0])
crime_ward_df_per_years.unstack().unstack()["2"].plot(figsize=(16,8),label="Ward2",legend=True,marker='o',color="0.6",ax=axes[0,1])
crime_ward_df_per_years.unstack().unstack()["3"].plot(figsize=(16,8),label="Ward3",legend=True,marker='o',color="0.6",ax=axes[0,2])
crime_ward_df_per_years.unstack().unstack()["4"].plot(figsize=(16,8),label="Ward4",legend=True,marker='o',color="0.6",ax=axes[0,3])
crime_ward_df_per_years.unstack().unstack()["5"].plot(figsize=(16,8),label="Ward5",legend=True,marker='o',color="0.6",ax=axes[1,0])
crime_ward_df_per_years.unstack().unstack()["6"].plot(figsize=(16,8),label="Ward6",legend=True,marker='o',color="0.6",ax=axes[1,1])
crime_ward_df_per_years.unstack().unstack()["7"].plot(figsize=(16,8),label="Ward7",legend=True,marker='o',color="0.6",ax=axes[1,2])
crime_ward_df_per_years.unstack().unstack()["8"].plot(figsize=(16,8),label="Ward8",legend=True,marker='o',color="0.6",ax=axes[1,3])

plt.savefig("crime_number_per_ward_over_time.png", dpi=300) # save as png

# %% [markdown]
# ##Objective 7. Crime distribution per day's shift. Statistical analysis.
#
# Let's see now which is the frequency of crimes within these three periodes of the day: day, evening and midnight.

# %% [markdown]
# **Hypothesis test for more than two proportions**
#
# I would like to know if the proportions of crimes per shift changed with time.
# To do that, I'll use the **chi-square test**. The difference between the observed cell counts and those expected given no association (with fixed marginal totals) are compared to a table of the chi-square distribution. Large differences indicate discrepancies over and above chance and that there is a real association.
#
# The following table compares the number of reported incidents per year among the three shifts.

# %%
df_shifts=pd.DataFrame({'2011':df2011.Shifts.value_counts(),'2012':df2012.Shifts.value_counts(),
                        '2013':df2013.Shifts.value_counts()})

df_shifts
#plt.savefig("Figure9.png",dpi=300) # save as png
# Out:
#            2011   2012   2013
# EVENING   14628  14686  15164
# DAY       12853  14441  14094
# MIDNIGHT   6481   6308   6638

# %% [markdown]
# And the proportions are:

# %%
def build_proportion_df():
    '''df with DAY, EVENING and MIDNIGHT proportions'''
    Shifts=['DAY', 'EVENING' , 'MIDNIGHT'] 
    proportions2011=[]
    proportions2012=[]
    proportions2013=[]
    years=['2011','2012','2013']
    for year in years:        
        for shift in Shifts:
            proportion=df_shifts[year].ix[shift]/df_shifts[year].sum()
            if year == '2011':
                proportions2011.append(round(proportion,4)*100)
            elif year == '2012':
                proportions2012.append(round(proportion,4)*100)
            else:
                proportions2013.append(round(proportion,4)*100)
            
            
    df=pd.DataFrame({'Shift':Shifts,'proportions2011':proportions2011,'proportions2012':proportions2012,'proportions2013':proportions2013})
    return df
prop_df=build_proportion_df()

prop_df.set_index('Shift')
# Out:
#           proportions2011  proportions2012  proportions2013
# Shift
# DAY                 37.85            40.75            39.26
# EVENING             43.07            41.44            42.24
# MIDNIGHT            19.08            17.80            18.49

# %% [markdown]
# **There is a relation between the shift day and the crime ocurrence? **
#
# Let's check it, here the hypothesis:
# * H<sub>0</sub>: No relation
# * H<sub>A</sub>: There is a relationship

# %%
DAY_total=round(df_shifts.ix['DAY'].sum(),2)
EVENING_total=round(df_shifts.ix['EVENING'].sum(),2)
MIDNIGHT_total=round(df_shifts.ix['MIDNIGHT'].sum(),2)


total_2011= df_shifts['2011'].sum()
total_2012= df_shifts['2012'].sum()
total_2013= df_shifts['2013'].sum()

TOTAL=DAY_total+EVENING_total+MIDNIGHT_total

#The proportion of crimes reported during the DAY is:
Day_proportion=round(DAY_total/TOTAL,4)
EVENING_proportion=round(EVENING_total/TOTAL,4)
MIDNIGHT_proportion=round(MIDNIGHT_total/TOTAL,4)

#Expected values (there are 9)
expected_CRIME_day_2011 = total_2011*Day_proportion
expected_CRIME_day_2012 = total_2012*Day_proportion
expected_CRIME_day_2013 = total_2013*Day_proportion

expected_CRIME_EVENING_2011 = total_2011*EVENING_proportion
expected_CRIME_EVENING_2012 = total_2012*EVENING_proportion
expected_CRIME_EVENING_2013 = total_2013*EVENING_proportion

expected_CRIME_MIDNIGHT_2011 = total_2011*MIDNIGHT_proportion
expected_CRIME_MIDNIGHT_2012 = total_2012*MIDNIGHT_proportion
expected_CRIME_MIDNIGHT_2013 = total_2013*MIDNIGHT_proportion

#print 'The overal proportion of crimes reported during the DAY is:',Day_proportion*100,'%'

# %%
DA2011=((12853-expected_CRIME_day_2011)**2)/expected_CRIME_day_2011
DA2012=((14441-expected_CRIME_day_2012)**2)/expected_CRIME_day_2012
DA2013=((14094-expected_CRIME_day_2013)**2)/expected_CRIME_day_2013

EV2011=((14628-expected_CRIME_EVENING_2011)**2)/expected_CRIME_EVENING_2011
EV2012=((14686-expected_CRIME_EVENING_2012)**2)/expected_CRIME_EVENING_2012
EV2013=((15164-expected_CRIME_EVENING_2013)**2)/expected_CRIME_EVENING_2013

MI2011=((6481-expected_CRIME_MIDNIGHT_2011)**2)/expected_CRIME_MIDNIGHT_2011
MI2012=((6308-expected_CRIME_MIDNIGHT_2012)**2)/expected_CRIME_MIDNIGHT_2012
MI2013=((6638-expected_CRIME_MIDNIGHT_2013)**2)/expected_CRIME_MIDNIGHT_2013

# %%
chi_2= DA2011+DA2012+DA2013+EV2011+EV2011+EV2011+MI2011+MI2012+MI2013
chi_2
# Out:
# 69.509618747319948

# %%
from scipy.stats import chi2
import scipy.stats

scipy.stats.chi2.pdf(chi_2 , 4)
# Out:
# 1.4001126663860678e-14

# %% [markdown]
# The p-value is 1.4001126663860678e-14 indicating that we must reject the null hypothesis. Then, there is a relationship
# among the shifts of the day and the crimes.

# %% [markdown]
# ##Objective 8. Find the crime distribution per months.
#
# Lets see now the crime distribution in function of dates.

# %%
months=['Jan','Feb','Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dic']

def crime_per_date_dataframe_builder(df,year):  
    
    df['Reported_Date'] = df['Reported_Date'].astype('datetime64[ns]')
    df_dates=df.set_index('Reported_Date')
    
    
    Jan = df[df['Reported_Date'].map(lambda x: x.month) == 1].Offenses.value_counts().sum()
    Feb = df[df['Reported_Date'].map(lambda x: x.month) == 2].Offenses.value_counts().sum()
    Mar = df[df['Reported_Date'].map(lambda x: x.month) == 3].Offenses.value_counts().sum()
    Apr = df[df['Reported_Date'].map(lambda x: x.month) == 4].Offenses.value_counts().sum()
    May = df[df['Reported_Date'].map(lambda x: x.month) == 5].Offenses.value_counts().sum()
    Jun = df[df['Reported_Date'].map(lambda x: x.month) == 6].Offenses.value_counts().sum()
    Jul = df[df['Reported_Date'].map(lambda x: x.month) == 7].Offenses.value_counts().sum()
    Aug = df[df['Reported_Date'].map(lambda x: x.month) == 8].Offenses.value_counts().sum()
    Sep = df[df['Reported_Date'].map(lambda x: x.month) == 9].Offenses.value_counts().sum()
    Oct = df[df['Reported_Date'].map(lambda x: x.month) == 10].Offenses.value_counts().sum()
    Nov = df[df['Reported_Date'].map(lambda x: x.month) == 11].Offenses.value_counts().sum()
    Dic = df[df['Reported_Date'].map(lambda x: x.month) == 12].Offenses.value_counts().sum()

    #months=['Jan','Feb','Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dic']
    incidents_month=[Jan,Feb,Mar, Apr, May, Jun, Jul, Aug, Sep, Oct, Nov, Dic]
    month_df=pd.DataFrame({'Months':months, 'Number_of_incidents_'+str(year):incidents_month})
    
    return month_df.set_index('Months')

dates_dfs=[crime_per_date_dataframe_builder(df2011,2011), crime_per_date_dataframe_builder(df2012,2012), crime_per_date_dataframe_builder(df2013,2013)]

total=pd.concat(dates_dfs,axis=1)

total
# Out:
#         Number_of_incidents_2011  Number_of_incidents_2012  \
# Months
# Jan                         2285                      3020
# Feb                         2155                      2391
# Mar                         2617                      2536
# Apr                         2464                      2578
# May                         2868                      2964
# Jun                         3015                      3017
# Jul                         3075                      3236
# Aug                         3015                      3438
# Sep                         3002                      3091
# Oct                         3293                      3282
# Nov                         3064                      2899
# Dic                         3109                      2983
#
#         Number_of_incidents_2013
# Months
# Jan                         2812
# Feb                         2249
# Mar                         2586
# Apr                         2705
# ...

# %%
total.plot(figsize=(15,4),marker='o',color=('b','r','g'))
plt.savefig("Crime_distribution_per_month.png", dpi=300) # save as png

# %% [markdown]
# Is there perhaps a **trend** behind this?
#
# Let's see the **average temperatures** for each month per year. To make this proccess easier I am gonna use the weather data from the **Reagan National Airport**, under the assumption that the average temperatures at the airport are representative of the **overall temperatures in DC**.
#
# Reagan National Airport weather link:
# http://www.wunderground.com/history/airport/KDCA/2013/12/1/MonthlyHistory.html?req_city=&req_state=&req_statename=&reqdb.zip=&reqdb.magic=&reqdb.wmo=

# %%
Temps2011=[1, 5, 8, 15, 20, 26, 29, 27, 22, 15, 12, 7]
Temps2012=[5, 7, 14, 15, 22, 25, 29, 27, 22, 16, 8, 7]
Temps2013=[5, 4, 7, 15, 19, 25, 27, 25, 22, 17, 8, 6] 
tempe_df=pd.DataFrame({'Months':months, 'T_C_2011':Temps2011,'T_C_2012':Temps2012,'T_C_2013':Temps2013 })


tempe_df.set_index('Months').plot(figsize=(15,4),marker='o',color=('b','r','g'))
plt.savefig("Figure7.png",dpi=300) # save as png

# %% [markdown]
# Definitively here seems to be a possible **correlation between colder weather and criminal activity**. Lets check it.

# %% [markdown]
# To do that we need:
#     * DF with the temperatures and the number of incidents per month for a given year
#     * A plot to represent the linear regresion.
#
# Then, first let's define a new function called Linear_regresion_df_builder that builts up the DF.

# %%
def Linear_regresion_df_builder(year):
    ''' Returns a DF with the temperatures and the number of incidents per month for a given year'''
    num_crime_year="Number_of_incidents_"+str(year)
    temp_year="T_C_"+str(year)
    T=[]
    num=[]
    for temperature,num_incidents in zip(tempe_df[temp_year],total[num_crime_year]):
        T.append(temperature)
        num.append(num_incidents)
    
    
    regresion_df= pd.DataFrame({'Temperatures_C':T,num_crime_year:num})
    
    return regresion_df

# %% [markdown]
# And now, define the plot builder function:

# %%
def Plot_regresion(year):
    '''plot the data'''
    num_crime_year="Number_of_incidents_"+str(year)    
    regresion=Linear_regresion_df_builder(year)
    regresion.plot( kind='Scatter', x='Temperatures_C',y=num_crime_year,
                                   figsize=(6, 4), title='Num_Incidents VS Temperature_ '+str(year),
                                   fontsize=14)
    plt.plot()
    X=regresion.Temperatures_C
    Y=regresion[num_crime_year]  
    p1=polyfit(X,Y,1)
    plt.plot(X,polyval(p1,X),color='r')
    
    slope,intercept,r_value,p_value,std_err=linregress(X,Y)

    print "The r-square value is:", round((pow(r_value,2)),2),"and the p-value is:",round((pow(p_value,2)),4)

# %% [markdown]
# How does it look and how good is the adjustment (r square)?

# %%
Plot_regresion(2011)
#plt.savefig("Figure8.png",dpi=300) # save as png
# Out:
# The r-square value is: 0.36 and the p-value is: 0.0017

# %% [markdown]
# We can say then that the **36% of the variability** in the Number of incidents in 2011 with the temperatures **is explained by the model**.
# Let's do **hypothesis testing** by seting the following hypothesis:
#
# * H<sub>0</sub>= SLOPE of the regresion line = 0
# * H<sub>A</sub>= SLOPE different than 0
#
# As we got a p-value of 0.17% we can reject the null hypothesis.
#
# It means that we can say that there is a **very weak** possitive linear correlation between the number of incidents registered in 2011 and the temperatures.

# %%
Plot_regresion(2012)
# Out:
# The r-square value is: 0.3 and the p-value is: 0.004

# %% [markdown]
# We can say then that the **30% of the variability** in the Number of incidents in 2012 with the temperatures **is explained by the model**.
#
# As we got a p-value of 0.04% we can reject the null hypothesis.
#
# It means that we can say that there is a **weak** possitive linear correlation between the number of incidents registered in 2011 and the temperatures.

# %%
Plot_regresion(2013)
# Out:
# The r-square value is: 0.57 and the p-value is: 0.0

# %% [markdown]
# We can say then that the **57% of the variability** in the Number of incidents in 2013 with the temperatures **is explained by the model**.
#
# As we got a p-value very close to 0.00% we can reject the null hypothesis.
#
# It means that we can say that there is a **moderate** possitive linear correlation between the number of incidents registered in 2011 and the temperatures.

# %% [markdown]
# ##Objective 9. Find if there is a correlation between the daily temperatures and the crime incident number
#
# The correlation exists but is **not good**. Let's see if it gets better taking crime data and mean tempreature per day:
#
# To achieve this goal, we need to scrap data from a web site. If you are interested in the Scraping process there is a file in the same folder "crime_data" called: ** Scrapping_temperatures_mechanize.ipynb **

# %% [markdown]
# * Let's check the temperatures per day.

# %%
temperatures_day_DF = pd.read_csv('temp_day',sep=',')
temperatures_day_DF['temperatures in C'].head()
# Out:
# 0    8
# 1    8
# 2    2
# 3    1
# 4    3
# Name: temperatures in C, dtype: int64

# %%
temperatures_day_DF['temperatures in C'].plot(color='b')

# %% [markdown]
# * And the number of incidents per day:

# %% [markdown]
# * Lets merge all this data together:

# %%
T=[]
C=[]
for i in temperatures_day_DF['temperatures in C']:
    T.append(i)
for i in df2011.groupby('Days').size():
    C.append(i)
for i in df2012.groupby('Days').size():
    C.append(i)
for i in df2013.groupby('Days').size():
    C.append(i)
    
len(T),len(C)
# Out:
# (1096, 1096)

# %%
crime_temp_per_day_DF=pd.DataFrame({'Temperature':T, 'Incidents':C})
crime_temp_per_day_DF.head()
# Out:
#    Incidents  Temperature
# 0         71            8
# 1         68            8
# 2         76            2
# 3         90            1
# 4         68            3

# %%
regresion=crime_temp_per_day_DF#.head(365)


x = regresion.Temperature
y = regresion.Incidents

fig, ax = plt.subplots(figsize=(12,4))
ax.scatter(x, y,alpha=0.5)

ax.set_xlim([min(x)-1, max(x)+1])
ax.set_xlabel('Temperature', fontsize=12)
ax.set_ylabel('Crime_means_per_temperature', fontsize=12)
ax.set_title('Means of number of incidents VS Temperature', fontsize=14)
                                   
ax.grid(True)
fig.tight_layout()

# %% [markdown]
# Here above we see as for each temperature we have different outcomes. Let's **calculate the mean** of incidents for a given temperature, **plot** it and **fit** it:

# %%
crime_temp_per_day_DF.Temperature.min()
# Out:
# -6

# %%
crime_temp_per_day_DF.Temperature.max()
# Out:
# 34

# %%
stds=[]
crime_means=[]
temps=[]
for i in range(-6,35): #Regresion
#for i in range(-4,35): #Regresion2
    temps.append(i)
    crime_means.append(crime_temp_per_day_DF[crime_temp_per_day_DF.Temperature==i].Incidents.mean())
    stds.append(crime_temp_per_day_DF[crime_temp_per_day_DF.Temperature==i].Incidents.std())

    
daily_temp_mean_crime=pd.DataFrame({'Crime_means_per_temperature':crime_means, 'Temperature':temps,'stds':stds})
daily_temp_mean_crime = daily_temp_mean_crime.fillna(0)

daily_temp_mean_crime.head(10)
# Out:
#    Crime_means_per_temperature  Temperature       stds
# 0                    95.500000           -6  14.849242
# 1                    69.000000           -5   0.000000
# 2                    82.666667           -4   9.073772
# 3                    86.000000           -3  15.556349
# 4                    74.000000           -2  22.226111
# 5                    77.266667           -1  13.624907
# 6                    78.571429            0  12.039617
# 7                    79.840000            1  14.562166
# 8                    83.714286            2  14.785611
# 9                    84.645161            3  15.465119

# %%
regresion=daily_temp_mean_crime

#regresion=daily_temp_mean_crime[daily_temp_mean_crime.Temperature>-5]

x = regresion.Temperature
y = regresion.Crime_means_per_temperature 
 

yerr = daily_temp_mean_crime.stds    
    
fig, ax = plt.subplots(figsize=(12,4))
ax.scatter(x, y,alpha=0.5)

ax.set_xlim([min(x)-1, max(x)+1])
ax.set_ylim([min(y)-18, max(y)+18])
ax.set_xlabel('Temperature', fontsize=12)
ax.set_ylabel('Crime_means_per_temperature', fontsize=12)
ax.set_title('Means of number of incidents VS Temperature', fontsize=14)
ax.errorbar(x, y, yerr=yerr, fmt='o',ecolor='0.6', capthick=0.5, alpha=0.9)



plt.plot()
X=regresion.Temperature  
Y=regresion.Crime_means_per_temperature  
p1=polyfit(X,Y,2)
plt.plot(X,polyval(p1,X),color='r')
    
slope,intercept,r_value,p_value,std_err=linregress(X,Y)

ax.grid(True)
fig.tight_layout()

print "The r-square value is:", round((pow(r_value,2)),2)
# Out:
# The r-square value is: 0.68

# %% [markdown]
# Although some people suggested a positive linear correlation between the temperature and the number of crimes,  this deeper analysis reveals a non linear behavior. Other research works as the one done by Janet L. and Jeremy J. Hess from the United States Environmental Protection Agency supports that trend for other cities such as Dallas (Texas).
#
# *Temperature and Violent Crime in Dallas, Texas: Relationships and Implications of Climate Change*
# * http://www.ncbi.nlm.nih.gov/pmc/articles/PMC3415828/

# %% [markdown]
# ##Objective 10: Crime frequency per street. Bubble plots.
#
# Let's see which were the places with a larger number of crimes registered.

# %%
Street_freq_df=pd.DataFrame({'2011':df2011.Street.value_counts(),'2012':df2012.Street.value_counts(),'2013':df2013.Street.value_counts()})

Street_freq_df = Street_freq_df.sort(columns='2013',ascending=False)
Street_freq_df.head(4)
# Out:
#                                             2011  2012  2013
# 3100 - 3299 BLOCK OF 14TH STREET NW          259   303   267
# 900 - 999 BLOCK OF RHODE ISLAND AVENUE NE     98   139   135
# 700 - 799 BLOCK OF 7TH STREET NW             111   124   132
# 1300 - 1699 BLOCK OF CONNECTICUT AVENUE NW   133   159   126

# %%
import plotly.plotly as py
import cufflinks as cf


cf.set_config_file(offline=False, world_readable=True, theme='ggplot')

#Street_freq_df=Street_freq_df
Street_freq_df.head(50).iplot(kind='barh',barmode='stack', bargap=.1, filename='cufflinks/barh',title='Top10 places in DC with larger number of crimes reported 2011-13')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~Diaz-Gallifa_P/47.embed" height="525px" width="100%"></iframe>

# %%
Street_freq_df.head(1)
# Out:
#                                      2011  2012  2013
# 3100 - 3299 BLOCK OF 14TH STREET NW   259   303   267

# %% [markdown]
# Let's plot a bubble chart now:
#
# to do that, I need the coordinates calculated in the file: **Get_coordinates_GOOGLE.ipynb**

# %%
df = pd.read_csv('Coordinates_crimes.csv', sep=',')
df.head(2)
# Out:
#    Unnamed: 0                                    Streets   Latitude  \
# 0           0        3100 - 3299 BLOCK OF 14TH STREET NW  38.929571
# 1           1  900 - 999 BLOCK OF RHODE ISLAND AVENUE NE  38.922396
#
#    Longitude  crime 2011  crime 2012  crime 2013        mean  \
# 0 -77.033196         259         303         267  276.333333
# 1 -76.993698          98         139         135  124.000000
#
#                                                 Text
# 0  Mean of incidents (2011-2013): 0     276.33333...
# 1  Mean of incidents (2011-2013): 0     276.33333...

# %%
import plotly.graph_objs as go
import colorlover as cl
from scipy.stats import gaussian_kde

# SepalWidth = Longitude
# PetalLength = Latitude

scl = cl.scales['9']['seq']['Blues']
colorscale = [ [ float(i)/float(len(scl)-1), scl[i] ] for i in range(len(scl)) ]
colorscale

def kde_scipy(x, x_grid, bandwidth=0.2 ):
    kde = gaussian_kde(x, bw_method=bandwidth / x.std(ddof=1) )
    return kde.evaluate(x_grid)

x_grid = np.linspace(df['Longitude'].min(), df['Longitude'].max(), 100)
y_grid = np.linspace(df['Latitude'].min(), df['Latitude'].max(), 100)

trace1 = go.Histogram2dContour(
    x=df['Longitude'],
    y=df['Latitude'],
    name='density',
    ncontours=20,
    colorscale=colorscale,
    showscale=False
)
trace2 = go.Histogram(
    x=df['Longitude'],
    name='x density',
    yaxis='y2',
    histnorm='probability density',
    marker=dict(color='rgb(217, 217, 217)'),
    nbinsx=25
)
trace2s = go.Scatter(
    x=x_grid,
    y=kde_scipy( df['Longitude'].as_matrix(), x_grid ),
    yaxis='y2',
    line = dict( color='rgb(31, 119, 180)' ),
    fill='tonexty',
)
trace3 = go.Histogram(
    y=df['Latitude'],
    name='y density',
    xaxis='x2',
    histnorm='probability density',
    marker=dict(color='rgb(217, 217, 217)'),
    nbinsy=50
)
trace3s = go.Scatter(
    y=y_grid,
    x=kde_scipy( df['Latitude'].as_matrix(), y_grid ),
    xaxis='x2',
    line = dict( color='rgb(31, 119, 180)' ),
    fill='tonextx',
)

#data = [trace1, trace2, trace2s, trace3, trace3s]
data = [trace1,  trace2,  trace3]

layout = go.Layout(
    showlegend=False,
    autosize=False,
    width=700,
    height=700,
    hovermode='closest',
    bargap=0,

    xaxis=dict(domain=[0, 0.746], linewidth=2, linecolor='#444', title='Longitude',
               showgrid=False, zeroline=False, ticks='', showline=True, mirror=True),

    yaxis=dict(domain=[0, 0.746],linewidth=2,linecolor='#444', title='Latitude',
               showgrid=False, zeroline=False, ticks='', showline=True, mirror=True),

    xaxis2=dict(domain=[0.75, 1], showgrid=False, zeroline=False, ticks='',
                showticklabels=False ),

    yaxis2=dict(domain=[0.75, 1], showgrid=False, zeroline=False, ticks='',
                showticklabels=False ),
)

fig = go.Figure(data=data, layout=layout)

# IPython notebook
py.iplot(fig, filename='pandas-2d-density-plot', height=700)

#url = py.plot(fig, filename='pandas-2d-density-plot')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;"seamless="seamless" src="https://plot.ly/~Diaz-Gallifa_P/85.embed" height="700px" width="700px"></iframe>

# %% [markdown]
# But, let's see it in a map!!!

# %%
from IPython.display import Image
Image(filename='MAP_CRIME_density.png')
